# %% [markdown]
# # Flyback converter

# %%
from cursusdef import *

# %%
display.Image("https://upload.wikimedia.org/wikipedia/commons/thumb/8/86/Flyback_conventions.svg/800px-Flyback_conventions.svg.png")
