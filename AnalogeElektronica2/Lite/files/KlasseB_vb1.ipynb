# %% [markdown]
# # Voorbeeld 1: Klasse B versterker

# %%
from cursusdef import *

# %%
display.Image("./images/ClassB_vb/vb1schema.png")

# %%
display.Image("./images/ClassB_vb/vb1intern.png")

# %%
display.Image("./images/ClassB_vb/vb1foto.png")

# %%
display.Image("./images/ClassB_vb/vb1layout.png")

# %% [markdown]
# {numref}`vb1bestuk` toont dan aan hoe deze print moet bestukt worden. De vermogenstransistors staan allemaal aan de rechterzijde wat het mogelijk maakt deze met de koelvin die je kan zien in {numref}`VBB1foto` te verbinden. We zien op deze foto ook dat er zowel zilvepasta als een geleidende schroef wordt gebruikt om deze goede verbinding met de koelvin te bekomen.

# %%
display.Image("./images/ClassB_vb/vb1bestukking.png")
