# %% [markdown]
# # Voorbeeld 3: Klasse B versterker

# %%
from cursusdef import *

# %% [markdown]
# In dit derde voorbeeld bsprekenen we een klasse B versterker die vermogenFETs heeft in de uitgangstrap.

# %%
display.Image("./images/ClassB_vb/vb3schema.png")

# %%
display.Image("./images/ClassB_vb/vb3foto.jpeg")

# %%
display.Image("./images/ClassB_vb/vb3layout.png")
