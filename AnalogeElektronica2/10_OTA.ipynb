# %% [markdown]
# # Operational transconductance amplifier (OTA)

# %% [markdown]
# ## Operational transconductance amplifier (OTA)
# Operational transconductance amplifier (OTA)
# jan.genoe@kuleuven.be

# %% [markdown]
# ### Notes — Slide 1
#
# In dit hoofdstuk behandelen we  de werking van de Operational transconductance amplifiers (OTA)

# %% [markdown]
# ## Operational transconductance amplifier (OTA)
# Zet een spanningsverschil om in stroom
# De transconductance gain Gm wordt gecontroleerd door de DC bias stroom IB
# Operational transconductance amplifier (OTA)
# iout

# %% [markdown]
# ## Belang van de OTA
# De toename in het gebruik van actieve filters heeft de OTA belangrijk gemaakt
# Bijvoorbeeld de niet-inverterende integrator wordt gerealiseerd aan de hand van een OTA zonder feedback
# het lineaire gedrag wordt dus behouden tot zeer hoge frequenties
# Belang van de OTA
# inverterende integrator kan ook

# %% [markdown]
# ## Andere OTA analoge schakelingen ()
# Inverterende spanningsversterker met belasting $R_L$
# Niet-inverterende spanningsversterker met belasting $R_L$
# Andere OTA analoge schakelingen ()
# vout
# vin
# $R_L$
# vout
# vin
# $R_L$

# %% [markdown]
# ## Andere OTA analoge schakelingen ()
# Regelbare weerstand
# Regelbare inverterende spanningsversterker met regelbare uitgangsimpedantie
# Andere OTA analoge schakelingen ()
# Zin
# vin
# vout

# %% [markdown]
# ### Notes — Slide 5
#
# Het tweede schema is ook een spanning scaler. Aan de hand van de verhoudingen van de Gms kunnen we de schaalfactor bepalen en deze  Gms worden dan weer bepaald door de verhoudingen van de instelstromen IB.

# %% [markdown]
# ## Opteller/aftrekker
# Twee of meer spanningen kunnen opgeteld worden, elk vermenigvuldigd met een factor bepaald door de Gm.
# Een aftrekking bekomt men door de ingangen van een van de OTA om te draaien
# Opteller/aftrekker
# vout

# %% [markdown]
# ## Andere OTA analoge schakelingen ()
# Impedantie omkeerder
# mogelijke impedanties
# weerstand
# capaciteit
# inductantie
# Andere OTA analoge schakelingen ()

# %% [markdown]
# ## Basis OTA schakeling: principes
# MOS verschilversterker met stroomspiegel als actieve belasting
# Stroombron (IB) zorgt voor alle instelspanningen
# Basis OTA schakeling: principes
# nMOS
# pMOS
# $V_{SS}$
# $V_{DD}$
# iout

# %% [markdown]
# ## Basis OTA schakeling: opmerkingen
# Alle substraten zijn verbonden met de source om de matching te verbeteren
# Basis OTA schakeling: opmerkingen
