# %% [markdown]
# # Voorbeeld 2: Klasse B versterker

# %%
from cursusdef import *

# %%
display.Image("./images/ClassB_vb/vb2schema.png")

# %%
display.Image("./images/ClassB_vb/vb2amplfier.png")

# %%
display.Image("./images/ClassB_vb/vb2foto.jpeg")

# %%
display.Image("./images/ClassB_vb/vb2layout.png")

# %%
display.Image("./images/ClassB_vb/vb2bestukking.png")
