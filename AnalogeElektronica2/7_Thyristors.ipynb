# %% [markdown]
# #

# %% [markdown]
# ##
# jan.genoe@kuleuven.be

# %% [markdown]
# ### Notes — Slide 1
#
# De foto toont een Thyristor die V en  A kan schakelen, gemount op een heat-sink. De dunne draden worden gebruikt voor de gate stroom.
# [] S. M. Sze and K. K. Ng, Physics of Semiconductor Devices. John Wiley & Sons, .
# [] http://en.wikipedia.org/wiki/Thyristor

# %% [markdown]
# ## Van  lagen naar  lagen
# lagen: een PN junctie diode
#  lagen: een bipolaire transistor
# NPN
# PNP
#  lagen: een thyristor
# NPNP
# Van  lagen naar  lagen

# %% [markdown]
# ## herhaling np junctie
# voorwaartse bias over de junctie
# De barrière voor elektronen en gaten is even hoog
# Alleen als de barrière verlaagt wordt hebben we stroom van elektronen en van gaten
# herhaling np junctie
# n:   cm-
# p:   cm-

# %% [markdown]
# ## herhaling np junctie
# voorwaartse bias over de junctie
# De barrière voor elektronen en gaten is even hoog
# Alleen als de barrière verlaagt wordt hebben we stroom van elektronen en van gaten
# herhaling np junctie

# %% [markdown]
# ## Stroom spannings relatie
# Voorwaartse stroom neemt exponentieel toe met de spanning
# Achterwaartse stroom neemt toe met de wortel van de spanning
# Stroom spannings relatie
# achterwaartse spanning

# %% [markdown]
# ## NPN: toevoegen van de collector
# NPN: toevoegen van de collector
# Als de basis-emitter spanning verandert, veranderen de stromen
# Als de collector spanning verandert, verandert er niets
# collector
# emitter
# basis
# n: cm-
# p:   cm-
# n:   cm-

# %% [markdown]
# ## NPN: toevoegen van de collector
# NPN: toevoegen van de collector
# Als de basis-emitter spanning verandert, veranderen de stromen
# Als de collector spanning verandert, verandert er niets
# collector
# emitter
# basis

# %% [markdown]
# ## Stroomversterking NPN of PNP
# Bij lage basisstroom IB is er weinig stroomversterking $\\beta_F$
# Stroomversterking NPN of PNP
# Log $\\beta_F$
# Log IB
# Lage injectie
# Hoge injectie

# %% [markdown]
# ## NPNP: thyristor lagenstructuur
# NPNP: thyristor lagenstructuur
# Middelste PN-junctie vangt in eerste instantie alle spanning op, maar dat blijft NIET duren
# collector
# emitter
# basis
# emitter
# basis
# collector

# %% [markdown]
# ## NPNP: thyristor lagenstructuur
# NPNP: thyristor lagenstructuur
# collector
# emitter
# basis
# p: cm-
# emitter
# basis
# collector
# n: cm-
# p:   cm-
# n:   cm-

# %% [markdown]
# ## Opstelling meten thyristor met  contacten
# Opstelling meten thyristor met  contacten

# %% [markdown]
# ## Model werking:  bipolaire transistors
# Alternatieve naam
# Thyristor met  contacten= Shockleydiode
# Model werking:  bipolaire transistors

# %% [markdown]
# ## Werking Shockleydiode
# Geen voorwaartse BE spanning  normaal geen collector stroom
# Achterwaartse BC spanning  lek achterwaartse PN junctie
# Lekstroom geeft basisstroom voor de andere bipolaire transistor
# Van zodra de lusversterking  is, springt de thyristor aan : $U_{BO}$
# Werking Shockleydiode
# $U_{BO}$ = Break Over Voltage

# %% [markdown]
# ## karakteristiek Shockleydiode
# karakteristiek Shockleydiode
# $U_{BO}$ = Break Over Voltage
# Van zodra de spanning boven $U_{BO}$
# Komt, springt de thyristor aan en
# dat blijft zo tot de spanning terug
# wordt

# %% [markdown]
# ## Condities aanslaan thyristor
# Hoge spanning ($U_{BO}$)
# Snelle stijging van de spanning (dU/dt)
# Stroominjectie aan een basiscontact (gate)
# Lichtinval op  van de  basissen
# temperatuurstijging
# Condities aanslaan thyristor

# %% [markdown]
# ## thyristor (of $\\mathrm{SCR}$)
# $\\mathrm{SCR}$=Silicon Controlled Rectifier
# thyristor (of $\\mathrm{SCR}$)

# %% [markdown]
# ## Werking van de $\\mathrm{SCR}$
# Werking van de $\\mathrm{SCR}$

# %% [markdown]
# ## Werking van de $\\mathrm{SCR}$
# Werking van de $\\mathrm{SCR}$

# %% [markdown]
# ## Karakteristiek van de $\\mathrm{SCR}$
# Geblokkeerde toestand
# Karakteristiek van de $\\mathrm{SCR}$

# %% [markdown]
# ## Karakteristiek van de $\\mathrm{SCR}$
# Karakteristiek van de $\\mathrm{SCR}$

# %% [markdown]
# ## Karakteristieken
# Karakteristieken

# %% [markdown]
# ## Schakelgedrag
# Schakelgedrag

# %% [markdown]
# ## Voorbeeld
# Spanningen en stromen
# Voorbeeld

# %% [markdown]
# ## Voorbeeld van een dimmer
# Voorbeeld van een dimmer

# %% [markdown]
# ### Notes — Slide 24
#
# [] https://en.wikipedia.org/wiki/Thyristor

# %% [markdown]
# ## Schakelen onder licht
# Schakelen onder licht

# %% [markdown]
# ## Triac
# opbouw en symbolen
# Triac

# %% [markdown]
# ### Notes — Slide 26
#
# [] http://en.wikipedia.org/wiki/TRIAC

# %% [markdown]
# ## Triac
# thyristors in  component
# Triac

# %% [markdown]
# ## quadranten van de triac
# quadranten van de triac

# %% [markdown]
# ### Notes — Slide 28
#
# [] http://en.wikipedia.org/wiki/TRIAC

# %% [markdown]
# ## TRIAC karakterieken
# Kwadrant + en -
# Kwadrant
# Kwadrant + : positieve poortspanning
# Kwadrant - : negatieve poortspanning
# Ua-Ia karakteristiek
# TRIAC karakterieken

# %% [markdown]
# ## TRIAC aansturing
# TRIAC aansturing

# %% [markdown]
# ## TRIAC stromen en spanningen
# Ohms belast
# TRIAC stromen en spanningen

# %% [markdown]
# ## Thyristoren Praktische uitvoering
# Thyristoren Praktische uitvoering

# %% [markdown]
# ## Thyristoren Praktische uitvoering
# Thyristoren Praktische uitvoering

# %% [markdown]
# ## Thyristoren Praktische uitvoering
# Thyristoren Praktische uitvoering

# %% [markdown]
# ## Thyristoren Praktische uitvoering watergekoeld
# Thyristoren Praktische uitvoering watergekoeld

# %% [markdown]
# ## Thyristoren Praktische uitvoering (Semitop)
# Thyristoren Praktische uitvoering (Semitop)

# %% [markdown]
# ## Thyristoren Praktische uitvoering (semipack)
# Thyristoren Praktische uitvoering (semipack)

# %% [markdown]
# ## Mos controlled Thyristor (MCT)
# Mos controlled Thyristor (MCT)

# %% [markdown]
# ### Notes — Slide 38
#
# [] V.A.K. Temple, “MOS-Controlled thyristors- A new class of power devices,” IEEE Transactions on Electron Devices, vol. , no. , pp. –, Oct. .
# De pMOS verhoogt de lading die naar de basis van de bipolaire transistor Q gaat, en zet de transistor dus aan.
# De nMOS vermindert de lading naar de basis van de bipolaire transistor Q en zet de thyristor dus af.

# %% [markdown]
# ## Mos controlled Thyristor (MCT)
# Mos controlled Thyristor (MCT)

# %% [markdown]
# ### Notes — Slide 39
#
# [] V.A.K. Temple, “MOS-Controlled thyristors- A new class of power devices,” IEEE Transactions on Electron Devices, vol. , no. , pp. –, Oct. .
