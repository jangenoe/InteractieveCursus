# %% [markdown]
# # Hybrids

# %% [markdown]
# ## Hybrids
# Hybrids
# jan.genoe@kuleuven.be

# %% [markdown]
# ### Notes — Slide 1
#
# In this chapter we discuss the use of  in circuits.
# [] https://en.wikipedia.org/wiki/Power_dividers_and_directional_couplers

# %% [markdown]
# ## Hybrid symbol
# Hybrid symbol

# %% [markdown]
# ## Transformer hybrid
# Transformer hybrid

# %% [markdown]
# ## Oldest hybrid: telephony
# Oldest hybrid: telephony

# %% [markdown]
# ## single wire bi-directional data
# single wire bi-directional data
# No closed loop

# %% [markdown]
# ## transformer hybrid impedance matching
# transformer hybrid impedance matching

# %% [markdown]
# ##

# %% [markdown]
# ## QUADRATURE HYBRIDS
# QUADRATURE HYBRIDS

# %% [markdown]
# ## Balanced Amplifier
# Balanced Amplifier

# %% [markdown]
# ### Notes — Slide 9
#
# In many case the input impedance of the amplifier does not match the characteristic impedance of the transmission line. So an important reflection of the signal will be obtained on the transmission line at the input.
# The same holds  for the output impedance of the amplifier and the transmission line connected to the output.
# When two exactly equal amplifiers are available, one would obtain twice the same reflected signal. By adding an  degree phase difference (i.e. +) on one of the signals, both reflected signal will cancel, both at the input and the output.
# Please note that in the forward path, signals in phase are added.

# %% [markdown]
# ## Balanced amplifier using
# Balanced amplifier using
# line
# line

# %% [markdown]
# ### Notes — Slide 10
#
# A transformer hybrid, combined with a transmission line ( e.g. length difference on the PCB) can be used to build a balanced amplifier.
# Please be aware that this only works for one frequency, as the length of a  degree transmission line fits with a quarter wavelength.

# %% [markdown]
# ## Changing one hybrid into another
# Changing one hybrid into another

# %% [markdown]
# ## combining power
# combining power

# %% [markdown]
# ### Notes — Slide 12
#
# Hybrids can be used to combine power  of different sources on the same transmission line, without shorting the sources.
# Both signals with different Phase and different frequencies can be  merged.

# %% [markdown]
# ## Wilkinson power divider and hybrid model
# Wilkinson power divider and hybrid model

# %% [markdown]
# ## Wilkinson power divider and hybrid model
# Wilkinson power divider and hybrid model

# %% [markdown]
# ## Hybrid ring
# Hybrid ring

# %% [markdown]
# ## Hybrid ring
# Hybrid ring

# %% [markdown]
# ### Notes — Slide 16
#
# Photograph of a microstrip ring hybrid: Courtesy of M. D. Abouzahra, MIT Lincoln Laboratory

# %% [markdown]
# ## Branch line hybrid
# Branch line hybrid

# %% [markdown]
# ### Notes — Slide 17
#
# This implementation can be made easily on PCB.

# %% [markdown]
# ## discrete  ()
# discrete  ()

# %% [markdown]
# ### Notes — Slide 18
#
# For lower frequencies, the transmission lines of the   would become too long. In this case they can be approximated by their corresponding capacitances and inductances.

# %% [markdown]
# ## discrete  ()
# discrete  ()

# %% [markdown]
# ### Notes — Slide 19
#
# For lower frequencies, the transmission lines of the   would become too long. In this case they can be approximated by their corresponding capacitances and inductances.

# %% [markdown]
# ## Backward coupler
# Backward coupler
