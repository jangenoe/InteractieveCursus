# %% [markdown]
# # Capacitive Power voltage conversion

# %% [markdown]
# ## Capacitive Power voltage conversion
# Capacitive Power voltage conversion
# jan.genoe@kuleuven.be

# %% [markdown]
# ### Notes — Slide 1
#
# It has always been difficult to implement large inductors on chip or in small devices. That’s why, for integrated systems, people have investigated how to use capacitive power contertors can be used for applications where the overall current drive is (rather) limited.

# %% [markdown]
# ## Step-up conversion
# Step-up conversion

# %% [markdown]
# ## Double the power voltage
# Double the power voltage
# DC power from AC power for
# high voltages
# low currents
# Very low ripple voltage

# %% [markdown]
# ## Double the power voltage
# Double the power voltage

# %% [markdown]
# ## Double the power voltage
# Double the power voltage

# %% [markdown]
# ## Double the power voltage
# Double the power voltage

# %% [markdown]
# ## Double the power voltage
# Double the power voltage

# %% [markdown]
# ## Extension to multiple steps
# Extension to multiple steps
# High voltages can be obtained without the need for
# expensive diodes
# expensive transformer
# expensive capacitors

# %% [markdown]
# ## Extension to multiple steps
# Extension to multiple steps

# %% [markdown]
# ## CMOS charge pump for doubling the power voltage on chip
# CMOS charge pump for doubling the power voltage on chip
# First $V_{DD}$ is placed over C
# Next C is placed in parallel with C
# The charge on C is distributed over both C and C.
# The obtained voltage depends on RL

# %% [markdown]
# ### Notes — Slide 10
#
# For further details, see:
# IEEE Journal of solid state circuits , - ()

# %% [markdown]
# ## Dickson charge pump
# Dickson charge pump
# After each diode, the voltage is increased with Vcc
# The last invertor is driven by CLK when N is odd.

# %% [markdown]
# ### Notes — Slide 11
#
# For further details, see:
# IEEE Journal of solid state circuits , - ()

# %% [markdown]
# ## Dickson charge pump using nMOS transistors
# Dickson charge pump using nMOS transistors
# nMOS transistors start conducting as soon as the voltage at the gate gets $V_T$ bigger as the voltage at the source

# %% [markdown]
# ## Step down conversion
# Step down conversion

# %% [markdown]
# ## stepdown convertor
# stepdown convertor
# [] A. Sarafianos and M. Steyaert, “Fully Integrated Wide Input Voltage Range Capacitive DC-DC Converters: The Folding Dickson Converter,”
# IEEE Journal of Solid-State Circuits, vol. , no. , pp. –, Jul. .

# %% [markdown]
# ### Notes — Slide 14
#
# Between the bracelets, it is indicated in which phase  which switch is activated. Here  stages are used, and  of the input voltage is obtained at the output. In general N stages are used and /(N+) is obtained at the output.

# %% [markdown]
# ## Multiple modes of operation
# Multiple modes of operation
# [] A. Sarafianos and M. Steyaert, “Fully Integrated Wide Input Voltage Range Capacitive DC-DC Converters: The Folding Dickson Converter,”
# IEEE Journal of Solid-State Circuits, vol. , no. , pp. –, Jul. .

# %% [markdown]
# ### Notes — Slide 15
#
# The above mentioned  convertor can also be used for making several output voltages, depending on how the switches are selected.

# %% [markdown]
# ## Multiple modes of operation
# Multiple modes of operation
# [] A. Sarafianos and M. Steyaert, “Fully Integrated Wide Input Voltage Range Capacitive DC-DC Converters: The Folding Dickson Converter,”
# IEEE Journal of Solid-State Circuits, vol. , no. , pp. –, Jul. .

# %% [markdown]
# ### Notes — Slide 16
#
# The above mentioned  convertor can also be used for making several output voltages, depending on how the switches are selected.

# %% [markdown]
# ## Multiple modes of operation
# Multiple modes of operation
# [] A. Sarafianos and M. Steyaert, “Fully Integrated Wide Input Voltage Range Capacitive DC-DC Converters: The Folding Dickson Converter,”
# IEEE Journal of Solid-State Circuits, vol. , no. , pp. –, Jul. .

# %% [markdown]
# ### Notes — Slide 17
#
# The above mentioned  convertor can also be used for making several output voltages, depending on how the switches are selected.

# %% [markdown]
# ## Multiple modes of operation
# Multiple modes of operation
# [] A. Sarafianos and M. Steyaert, “Fully Integrated Wide Input Voltage Range Capacitive DC-DC Converters: The Folding Dickson Converter,”
# IEEE Journal of Solid-State Circuits, vol. , no. , pp. –, Jul. .

# %% [markdown]
# ### Notes — Slide 18
#
# The above mentioned  convertor can also be used for making several output voltages, depending on how the switches are selected.
