# %% [markdown]
# # Noise

# %% [markdown]
# ## Noise
# Noise
# jan.genoe@kuleuven.be

# %% [markdown]
# ### Notes — Slide 1
#
# In this chapter we discuss the different noise sources present in electronics circuits and the impact on the output signals. Obviously, once you are able to calculate the impact, you are also able to optimize the design.

# %% [markdown]
# ## Thermal Noise (Johnson noise) of a resistor
# Finds its origin in the movement of electrons under the influence of temperature.
# Is "white noise", i.e. all frequencies contribute equally
# The power of this noise is:
# With B the bandwidth of the system under consideration
# With T the absolute temperature of the resistor
# With k the Boltzmann constant
# Thermal Noise (Johnson noise) of a resistor

# %% [markdown]
# ### Notes — Slide 2
#
# One can ask the question: “What if the system had an infinite bandwidth?” According to the equation above, the system would have an infinite noise power. This is not possible.
# A more detailed analysis of the fundamental principles yielding this equation leads to the conclusion that the formula is only valid as long as kT> hn. [1] At room temperature, we can conclude that the maximum frequency equals 1013 Hz or 10 THz. For most of the systems we design we can conclude as a consequence that the noise is independent of the frequency (i.e. white noise), unless the system is at extremely low temperatures.
# [1] J. B. Johnson. “Thermal Agitation of Electricity in Conductors.” Physical Review 32, July 1928

# %% [markdown]
# ## Introducing a noise source into a schematic
# Thévenin equivalent of the resistor
# We place a voltage source in series
# Introducing a noise source into a schematic
# Norton equivalent  of the resistor
# We place a current source in parallel
# vRMS
# iRMS

# %% [markdown]
# ## Combination of noise sources
# Noise voltages nor noise currents of different origin can never be added.
# Their squares (i.e. power) can be added.
# Example: we place R1 and R2 in parallel
# By adding the squares of the noise currents we get an equal result as if we would have calculated the noise current of the resistance having an equal value as the parallel connection of both resistances.
# Example: we place R1 and R2 in series
# By adding the squares of the noise voltages we get an equal result as if we would have calculated the noise voltage of the resistance having an equal value as the series connection of both resistances.
# Combination of noise sources

# %% [markdown]
# ## Example
# A pick-up cell of a turntable (vinyl plates) has an internal resistance of 2kW. The HiFi amplifier that traits the outcoming signal has a bandwidth of 20kHz. The noise level equals as a consequence 0.8 mV.
# A maximum amplitude, such a pick-up cell can deliver 10 mV
# The signal-noise (S/N) is at maximum amplitude (10 mV/0.8 mV)2
# The signal-noise is always a ration between two powers
# The dynamic range is hence 82 dB
# This is in the assumption that there is no additional noise introduced and that the needle follow the plate perfectly.
# Often signal compression is used to further increase the dynamic range.
# Example

# %% [markdown]
# ### Notes — Slide 5
#
# If one compares this with a CD, the actual dynamic range of a CD (16 bit system) is not too much larger (96 dB). Obviously, in the analog and mechanical system, one has many other noise sources, beside the pick-up cell.

# %% [markdown]
# ## Noise power of a linear passive network
# The Nyquist theorem imposes that the RMS noise voltage of a random linear passive network is given by:
# R is the real part of the impedance Z = R +j X
# R is hence frequency dependent
# Noise power of a linear passive network

# %% [markdown]
# ## Example: resistor + capacitor
# Example: resistor + capacitor

# %% [markdown]
# ## Assessment: resistor + capacitor
# The resistance remains the noise source, but the capacitor shorts the noise from a certain frequency
# Normally, one would expect that the 3dB frequency as the obtained bandwidth:
# However, this is not the case, the effective bandwidth is:
# Assessment: resistor + capacitor

# %% [markdown]
# ## Noise figure of an amplifier
# This noise figure is determined by adding the minimal noise power at the input of the amplifier under matched conditions (Ninput = kToB)
# Also in the case that we will never match the amplifier in reality
# The noise figure F is defined at To=290°K
# The amplification (G) in this equation is the power amplification
# Noise figure of an amplifier

# %% [markdown]
# ### Notes — Slide 9
#
# Why do we select the minimal noise at the input to calculate the noise figure F? If we would add more noise at the input, the relative contribution of the noise of the amplifier would be less, also reducing as a consequence the of the obtained F (i.e. better F). But this would not represent the optimal use of the amplifier.
# Assignment:
# Prove that when the amplifier is matched, the delivered power to the amplifier equals kToB. What is the noise power delivered when the amplifier is not matched?

# %% [markdown]
# ## Additional noise temperature of an amplifier
# This is a different way of phrasing the Noise Figure
# It appears that the noise at the input comes from a source at a different temperature.
# Additional noise temperature of an amplifier

# %% [markdown]
# ## Cascade connection of amplifiers
# we assume that each amplifier has a linear power amplification Gi
# We assume that the output impedance is always matched with the input impedance of the next stage
# We assume that each amplifier has the same bandwidth.
# The noise figure of the first amplifier dominates the overall noise figure.
# Cascade connection of amplifiers
# ...
# n-1

# %% [markdown]
# ### Notes — Slide 11
#
# To derive this formula, we proceed as follows:
# We start from the first stage with standard noise kToB at the input.
# We split the noise at the input of every stage i in two parts:
# Standard noise kToB
# Remaining noise
# We trait each part of the noise power differently:
# The standard noise is multiplied with GiFi (This is the definition of the noise figure)
# The remaining noise is treated as if it was a signal, i.e. we multiply with Gi.

# %% [markdown]
# ## Noise measure of an amplifier
# is the noise figure of an infinite chain of equal amplifiers
# Is a much better measure of the quality of an amplifier
# Is only valid for an amplification G $> 1$
# Noise measure of an amplifier

# %% [markdown]
# ## Transmission line
# Every transmission line has losses
# The signal gets weaker
# The noise remains the same
# The noise that is lost by the attenuation is added again by the resistance that causes the attenuation.
# The losses are characterized by the attenuation coefficient a.
# Transmission line

# %% [markdown]
# ## Influence of mismatch
# Influence of mismatch.
# Mismatch causes less signal and less noise at the input
# The noise generated inside the amplifier does not change
# Mismatch will as a consequence always decrease the noise performance of a circuit.
# Influence of mismatch

# %% [markdown]
# ## Shot noise: origin
# When transport of individual electrons through a space charge region occurs, the total current is the sum of individual small currents.
# The sum of this current is given by the diode current equation but there is also a variation on this current.
# This variation is the shot noise.
# Shot noise: origin

# %% [markdown]
# ## Shot noise of a diode
# Shot noise of a diode
# Without an external applied voltage the noise is defined by the cut-off current Io that runs in both directions through the diode, yielding a total current zero.
# On top of this we add the forward current IDC
# This is even a very accurate way to determine the charge q of the electron.

# %% [markdown]
# ## Shot noise of a diode (only when IR is constant)
# Shot noise of a diode (only when IR is constant)
# Without an external applied voltage the noise is defined by the cut-off current Io that runs in both directions through the diode, yielding a total current zero.
# On top of this we add the forward current IDC
# This is even a very accurate way to determine the charge q of the electron.

# %% [markdown]
# ## Validity of this equation
# An electron needs a certain time to move through the space charge region: this is the transit time.
# This equation is valid until a frequency which is the inverse of the transit time.
# This frequency is normally higher than the frequencies in use in our designs.
# For higher frequencies, the contribution to this noise decreases.
# Validity of this equation

# %% [markdown]
# ## Comparison with the differential resistance
# When we look at this we could say:
# “a junction has half the noise of a resistor"
# This is not correct:
# The origin of this noise is totally different, there is no physical resistance
# Comparison with the differential resistance

# %% [markdown]
# ## 1/f noise
# The origin of this noise are the changes in conduction mechanism, i.e. the changes of the conduction paths.
# The frequency f1 is defined as the frequency where this frequency equals the shot noise.
# 1/f noise

# %% [markdown]
# ### Notes — Slide 20
#
# So in a practical design: Only use carbon resistors when:
# These is no DC current through the resistor
# When you operate the circuit at high frequencies
# When noise is not so important

# %% [markdown]
# ## Popcorn noise, burst noise
# This noise is proportional to 1/f2
# In audio devices, it appears as a plop.
# The amplitude is typical 1/1000 of the current
# Is related with localized defects in the semiconductors
# Popcorn noise, burst noise

# %% [markdown]
# ## Generation-recombination noise
# flat at low frequencies
# proportional to 1/f in the audio region
# proportional to 1/f2 for higher frequencies
# proportional to the current through the semiconductor
# proportional to the number of recombination centers
# Generation-recombination noise

# %% [markdown]
# ## Noise of a bipolar transistor
# This noise comprises different  components:
# The noise of the resistance of the basis
# shot noise of the base current
# carriers from the base to the emitter
# shot noise of the collector current
# carriers from the emitter to the collector
# Noise of a bipolar transistor
