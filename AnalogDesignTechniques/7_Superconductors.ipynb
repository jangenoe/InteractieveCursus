# %% [markdown]
# # inelectronic circuits

# %% [markdown]
# ## inelectronic circuits
# inelectronic circuits
# jan.genoe@kuleuven.be

# %% [markdown]
# ## Example of a superconductor
# This cable can conduct A at a temperature of  K (-°C)
# The internal of this cable comprises a ceramic high Tc material and is surrounded by  layers of silver tape
# Producer: Perilli cable (USA)
# Example of a superconductor

# %% [markdown]
# ## What is superconductivity?
# Most non-magnetic metals and a few ceramic crystals show a resistance that equals exactly zero when the temperature falls below the critical temperature Tc.
# Tc strongly depends on:
# the current density
# the magnetic field
# The use of superconductors can be interesting because:
# No losses occur in the resistances (dissipation is an important constraint in the scaling down of semiconductor circuits).
# There are no longer RC delays. A connection must be modeled by its LC equivalent (ideal transmission line).
# What is superconductivity?

# %% [markdown]
# ### Notes — Slide 3
#
# [] T. Y. Chen, Z. Tesanovic, R. H. Liu, X. H. Chen & C. L. Chien,  “A BCS-like gap in the superconductor SmFeAsO.F.”, Nature ()

# %% [markdown]
# ## The  birth of a Cooper pair
# The  birth of a Cooper pair

# %% [markdown]
# ### Notes — Slide 4
#
# From the global perspective, a crystal is always neutral. This implies that the charges of the free electrons is compensated by an equal but opposite charge of the ions.  But on a local scale, it is obvious that charges matter and that local potentials are induced. At first glance this yields in a situation that both electron charges will be repelled from each other by their electric field. This will be definitely true if they get close to each other. However, when they reside at a bit longer distance from each other this is not necessary true due to the fact that the first  electron () attracts fixed ion charges from its neighborhood. As a consequence, the surrounding of electron () will look like a positive charge from a distance, and like a negative charge when electron () gets closer. Electron  () will be attracted by electron () and vice versa and they will form a pair that will reside at a fixed distance from each other. This pair is called a Cooper pair, as they have  been discovered by mister Cooper. This Cooper pair formation  is only happening when the movement of the ions, due to temperature is only limited. As a consequence, superconductivity will only occur at low temperatures. The energy of a Cooper pair is lower than the sum of the energies of the two individual electrons. We name this energy difference the  superconductivity gap D.  Cooper pairs can move freely. However, they behave completely different from electrons. They prefer to move together all coordinated. As a consequence, the do not have collisions with the ions of the lattice, and the  movement does not contribute to resistance.

# %% [markdown]
# ## Properties of superconductors
# Magnetic fields are expelled
# A current is generated that created the opposite field.
# Current that flows in a loop runs forever
# longest experiment : . year
# Until , the Tc of most known superconductors was between K and  K
# Currently superconductors are known with a Tc until K (-°C)  or even K ( GPa)
# These are ceramic materials of the class YBCO (Yttrium-Barium-Copper-Oxide)
# These superconductors have a layered structure.
# Properties of superconductors

# %% [markdown]
# ## Evolution of superconductivity
# Evolution of superconductivity

# %% [markdown]
# ### Notes — Slide 6
#
# [] T. Y. Chen, Z. Tesanovic, R. H. Liu, X. H. Chen & C. L. Chien,  “A BCS-like gap in the superconductor SmFeAsO.F.”, Nature ()

# %% [markdown]
# ## Josephson junction
# A Josephson junction is an utterly thin isolator between  superconductors.
# A superconductive current can pass through this junction until a maximum current (i.e. without voltage drop).
# As soon as one exceeds this maximum current, a voltage drop D over the junction is obtained (memory behavior)
# Removing all current can bring back the superconductivity
# Josephson junction

# %% [markdown]
# ## logic gates using Josephson junctions
# There are  ways to switch:
# by injecting a current
# by magnetic coupling
# logic gates using Josephson junctions

# %% [markdown]
# ### Notes — Slide 8
#
# There are two ways to get a voltage over a Josephson junction:  Current injection or a magnetic field. After switching, the voltage is maintained until the current is reduced until zero. Therefor, each clock period, the Ibias is removed. In reality we prefer to used squids (a loop of  or more Josephson junctions), because this results in a better noise reduction.

# %% [markdown]
# ## logic gates using Josephson junctions ()
# Typical voltages are . mV, and reasonably large current, such that capacitances can be charged quickly.
# Most gates are non-inverting. We can solve this by using differential logic and by using always both polarities.
# The AC power supply and clock distribution is very difficult
# Interfacing normal circuits is also very though: the .mV must be converted to a normal voltage, and this causes time delays.
# logic gates using Josephson junctions ()

# %% [markdown]
# ## Example of a MVTL layout
# Example of a MVTL layout

# %% [markdown]
# ## example of the switching of an MVTL gate
# example of the switching of an MVTL gate

# %% [markdown]
# ## Conclusion
# The fastest digital circuits can be realized using superconductors
# The design is very complex and the employment is very expensive
# Only when performance needs to be extreme, one can consider superconductive gates.
# If superconductivity ever could be used t room temperature, this could change drastically
# Todays most important applications:
# Very sensitive detection of EM radiation
# SQUID e.g. in medical imaging
# High-frequent filters with a very high Q
# This is because inductance with resistance can be obtained
# Conclusion
